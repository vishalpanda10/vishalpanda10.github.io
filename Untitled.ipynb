# %%
# !find . -type f -not -path '*/\.*'
# Out:
# ./blogs/page/1/index.html
# ./blogs/page/2/index.html
# ./blogs/index.html
# ./blogs/index.xml
# ./blogs/rich-content/index.html
# ./blogs/rich-content/index.xml
# ./blogs/emoji-support/index.html
# ./blogs/emoji-support/index.xml
# ./blogs/markdown-syntax/index.html
# ./blogs/markdown-syntax/index.xml
# ./blogs/math/index.html
# ./blogs/math/index.xml
# ./blogs/placeholder-text/index.html
# ./blogs/placeholder-text/index.xml
# ./404.png
# ./fontawesome-6/svgs/brands/supple.svg
# ./fontawesome-6/svgs/brands/x-twitter.svg
# ./fontawesome-6/svgs/brands/bootstrap.svg
# ./fontawesome-6/svgs/brands/weixin.svg
# ./fontawesome-6/svgs/brands/connectdevelop.svg
# ./fontawesome-6/svgs/brands/medium.svg
# ./fontawesome-6/svgs/brands/square-facebook.svg
# ./fontawesome-6/svgs/brands/ioxhost.svg
# ./fontawesome-6/svgs/brands/fonticons.svg
# ./fontawesome-6/svgs/brands/figma.svg
# ./fontawesome-6/svgs/brands/reddit-alien.svg
# ./fontawesome-6/svgs/brands/angrycreative.svg
# ...
